# %%
# Pandas is a software library written for the Python programming language for data manipulation and analysis.
import pandas as pd
# NumPy is a library for the Python programming language, adding support for large, multi-dimensional arrays and matrices, along with a large collection  of high-level mathematical functions to operate on these arrays.
import numpy as np
# Matplotlib is a plotting library for python and pyplot gives us a MatLab like plotting framework. We will use this in our plotter function to plot data.
import matplotlib.pyplot as plt
# %matplotlib inline
#Plotly provides number of trace objects such as scatter, bar, pie, heatmap etc. and each is returned by respective functions in graph_objs functions.
import plotly.graph_objs as go
#To create subplots
from plotly.subplots import make_subplots
#The plotly.express module (usually imported as px) contains functions that can create entire figures at once, and is referred to as Plotly Express or PX.
import plotly.express as px
#Seaborn is a Python data visualization library based on matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics
#This affects things like the color of the axes, whether a grid is enabled by default, and other aesthetic elements.
import seaborn as sns;sns.set(style="ticks", color_codes=True)
#Requests is a HTTP library for the Python programming language. The goal of the project is to make HTTP requests simpler and more human-friendly.
import requests
# The io module provides Python’s main facilities for dealing with various types of I/O. There are three main types of I/O: text I/O, binary I/O and raw I/O.
import io
# To work with date time variables
import datetime as dt

# %%
# Setting this option will print all collumns of a dataframe
pd.set_option('display.max_columns', None)
# Setting this option will print all of the data in a feature
pd.set_option('display.max_colwidth', None)
# Setting this option will print all of the data in a row
pd.set_option('display.max_rows',None)

# %%
Hvalue_Income_percent = pd.read_csv("G:\My Drive\Data Science and Machine Learning\ML and DS Projects\Projects\Hoom\Affordability\House_value_vs_Income_percetage_change.csv")
Hvalue_Income_percent.head()
# Out:
#    Year  House value change %  Income Change %
# 0  1965                  0.00             0.00
# 1  1970                  0.03             2.70
# 2  1975                 15.32             0.13
# 3  1976                 23.47             1.69
# 4  1977                 28.36             2.23

# %%
fig = px.line(Hvalue_Income_percent,
              x='Year',
              y=['House value change %','Income Change %'],
              title='United States House value and Income change rate',height=500).update_layout(xaxis_title="Year", yaxis_title="Price-to-Income Rate")
fig.show()

# %%
home_price_affordability = pd.read_csv("G:\My Drive\Data Science and Machine Learning\ML and DS Projects\Projects\Hoom\Affordability\Home Price Affordability.csv")
home_price_affordability.head()
# Out:
#          Date  Home Price Affordability Median HHI  \
# 0  1971-04-15                                 0.78
# 1  1971-05-15                                 0.79
# 2  1971-06-15                                 0.80
# 3  1971-07-15                                 0.81
# 4  1971-08-15                                 0.81
#
#    Home Price Affordability 25% HHI  Home Price Affordability 75% HHI  \
# 0                              1.50                              0.51
# 1                              1.52                              0.51
# 2                              1.54                              0.52
# 3                              1.56                              0.53
# 4                              1.55                              0.53
#
#    Median Home Price
# 0           25807.94
# 1           25996.93
# 2           26269.92
# 3           26311.92
# 4           26395.91

# %%
fig = make_subplots(specs=[[{"secondary_y": True}]])

#Add traces
fig.add_trace(go.Scatter(x=home_price_affordability['Date'],y=home_price_affordability['Home Price Affordability Median HHI'],name='Home Price Affordability Median HHI'),secondary_y=False)
fig.add_trace(go.Scatter(x=home_price_affordability['Date'],y=home_price_affordability['Home Price Affordability 25% HHI'],name='Home Price Affordability 25% HHI'),secondary_y=False)
fig.add_trace(go.Scatter(x=home_price_affordability['Date'],y=home_price_affordability['Home Price Affordability 75% HHI'],name='Home Price Affordability 75% HHI'),secondary_y=False)
fig.add_trace(go.Scatter(x=home_price_affordability['Date'],y=home_price_affordability['Median Home Price'],name='Median Home Price'),secondary_y=True)

#Title
fig.update_layout(title_text='Home Price Affordability in the United States',height=500)

#X-axis title
fig.update_xaxes(title_text='Date')

#Y-axis titles
fig.update_yaxes(title_text='Home Affordability',secondary_y=False)
fig.update_yaxes(title_text='Median Home Price',secondary_y=True)

fig.show()
